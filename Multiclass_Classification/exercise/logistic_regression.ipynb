# %%
# Import Libraries
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
# Load iris
iris = load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
# The Iris dataset contains measurements of 150 iris flowers from three species: setosa, versicolor, and virginica. 
# Each flower has four features: sepal length, sepal width, petal length, and petal width (all in cm). The dataset includes:
# data: 150 samples × 4 features (flower measurements).
# target: Labels for species (0 = setosa, 1 = versicolor, 2 = virginica).
# target_names: Names of the three species.
# feature_names: Names of the four features.
# DESCR: Full description of the dataset.
iris['data']
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
# Target refers to Labels for species (0 = setosa, 1 = versicolor, 2 = virginica).
iris.target[0:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# Split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2)
len(X_train)
len(X_test)
# Out:
# 30

# %%
# Call the Logistic Regression dataset
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
# What is the score of the model
model.score(X_test, y_test)
# Out:
# 1.0

# %%
# What is the label of 67
iris.target[67]
# Out:
# np.int64(1)

# %%
# Lets predict this image 67
model.predict([iris.data[67]])
# Out:
# array([1])

# %%
# Lets predict the iris
model.predict(iris.data[0:5])
# Out:
# array([0, 0, 0, 0, 0])

# %%
# Lets see which flower are not being predicted well
y_predicted = model.predict(X_test)
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[ 9,  0,  0],
#        [ 0, 14,  0],
#        [ 0,  0,  7]])

# %%
# We can see it better here
# For example all flowers are being represented well
import seaborn as sn
plt.Figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# Text(50.722222222222214, 0.5, 'Truth')
